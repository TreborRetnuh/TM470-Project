# %% [markdown]
# # TM470 Project - Automating the Identification of UK Coarse Fish

# %%
import tensorflow as tf
import kaggle
import pandas as pd
import os
import numpy as np
import sklearn
from sklearn.model_selection import StratifiedShuffleSplit #scikit-learn.org
from sklearn.model_selection import train_test_split
import pathlib
import matplotlib
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
import xml.etree.ElementTree as et # https://docs.python.org/3/library/xml.etree.elementtr
from tensorflow.python.client import device_lib #for detection of devices
import glob as glob # Searches for certain files
# for model
import keras
from tensorflow.keras import Sequential, optimizers, metrics, layers
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Rescaling

# %%
# TensorFlow version
print(tf.__version__)
# Out:
# 2.6.0

# %% [markdown]
# ### 3 Is TF using GPU acceleration from inside python shell.

# %%
# Is TF using GPU?
if tf.test.gpu_device_name():
    print('Default GPU device:{}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Number of GPU's available
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Details of CPU and GPU from the device library (device_lib)
print(device_lib.list_local_devices())
# Out:
# Default GPU device:/device:GPU:0
# Num GPUs Available:  1
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1000729162241830040
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6925844480
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11582896543501847860
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1070 Ti, pci bus id: 0000:06:00.0, compute capability: 6.1"
# ]

# %% [markdown]
# ### AFFiNe dataset from Kaggle (list, download and unzip)

# %% [markdown]
# ### Classes taken out of original dataset
# Aspius aspius Asp, Carassius gibelio (Carp Prussian), Lepomis gibbosus Pumpkinseed, Neogobius fluviatilis Goby (monkey), Neogobius kessleri Goby (bighead), Neogobius melanostomus (Goby Round), Rhodeus amarus Bitterling (European), Vimba vimba Vimba, Leuciscus leuciscus Dace, Gasterosteus aculeatus Stickleback.

# %%
# AFFiNe dataset from Kaggle placed in Jupyter folder
# https://www.kaggle.com/datasets/jorritvenema/affine

# %%
datasetPath = 'UK AFFiNe Split/Main'
testDatasetPath = 'UK AFFiNe Split/Test'

# %%
datasetPath, testDatasetPath
# Out:
# ('UK AFFiNe Split/Main', 'UK AFFiNe Split/Test')

# %%
# Assigning dataset path to pathlib
dat_dir = pathlib.Path(datasetPath).with_suffix('')
print(dat_dir)
# Out:
# UK AFFiNe Split\Main

# %%
test_dat_dir = pathlib.Path(testDatasetPath).with_suffix('')
print(test_dat_dir)
# Out:
# UK AFFiNe Split\Test

# %%
# Number of images in Main dataset
image_count = len(list(dat_dir.glob('*/*.jpg'))) # is this how datasetPath should be?
print(image_count)
# Out:
# 5362

# %%
# Number of images Test in dataset
image_count = len(list(test_dat_dir.glob('*/*.jpg'))) # is this how datasetPath should be?
print(image_count)
# Out:
# 600

# %% [markdown]
# # Get class names and bound box information from XML files using the parser

# %%
# Reading the information in the XML files and extracting names/bounding box info
path = (dat_dir)
filelist = []
list1 = list()
list2 = list()
for root, dirs, files in os.walk(path):
    for file in files:
        if not file.endswith('.xml'):
            continue
        filelist.append(os.path.join(root, file))
for file in filelist:
    root = et.parse(file).getroot() # get the root of the xml
# Get class names
    for className in root.findall('.//object'):
        class_name = className.find('name').text
        data = np.array([class_name])
    list1.append(data)
# Get bounding box information
    for bndBox in root.findall('.//object'):
        bounding_box = bndBox.find('bndbox').text
        xmin = int(bndBox.find('./bndbox/xmin').text)
        ymin = int(bndBox.find('./bndbox/ymin').text)
        xmax = int(bndBox.find('./bndbox/xmax').text)
        ymax = int(bndBox.find('./bndbox/ymax').text)
        data2 = np.array([xmin,ymin,xmax,ymax])
    list2.append(data2)

# %%
print(len(list1))
# Out:
# 5362

# %% [markdown]
# ## Create dataframe (using relative paths, class names and bound box details from XML)

# %%
#list(base_dir.glob('*/*.jpg'))
filepaths = list(dat_dir.glob(r'**/*.jpg'))
classnames = list1#list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))
boundboxes = list2

filepaths = pd.Series(filepaths, name='Filepath').astype(str)#str
classnames = pd.Series(classnames, name='Class Name')
boundboxes = pd.Series(boundboxes, name='Boundbox')

dataframe1 = pd.concat([filepaths , classnames, boundboxes] , axis=1)
dataframe1
# Out:
#                                                Filepath       Class Name  \
# 0     UK AFFiNe Split\Main\Abramis brama\017f3e53-e0...  [Abramis brama]
# 1     UK AFFiNe Split\Main\Abramis brama\022e3ceb-a8...  [Abramis brama]
# 2     UK AFFiNe Split\Main\Abramis brama\02436d5d-04...  [Abramis brama]
# 3     UK AFFiNe Split\Main\Abramis brama\08282fac-ad...  [Abramis brama]
# 4     UK AFFiNe Split\Main\Abramis brama\08ff200c-a6...  [Abramis brama]
# ...                                                 ...              ...
# 5357  UK AFFiNe Split\Main\Tinca tinca\f917c866-9230...    [Tinca tinca]
# 5358  UK AFFiNe Split\Main\Tinca tinca\f96c7997-7f5d...    [Tinca tinca]
# 5359  UK AFFiNe Split\Main\Tinca tinca\fbd1d021-5b64...    [Tinca tinca]
# 5360  UK AFFiNe Split\Main\Tinca tinca\fd1a5781-0723...    [Tinca tinca]
# 5361  UK AFFiNe Split\Main\Tinca tinca\fdef10a4-0a00...    [Tinca tinca]
#
#                 Boundbox
# 0     [20, 20, 515, 187]
# 1     [20, 20, 283, 916]
# 2     [20, 20, 697, 244]
# 3     [19, 20, 789, 400]
# 4     [20, 20, 556, 214]
# ...                  ...
# 5357  [13, 20, 772, 346]
# 5358  [20, 20, 725, 365]
# 5359  [20, 20, 651, 270]
# 5360  [20, 20, 641, 269]
# 5361  [20, 20, 563, 318]
#
# [5362 rows x 3 columns]

# %%
# species counts for each class with UK AFFiNe

dataframe1['Class Name'].value_counts()
# Out:
# [Cyprinus carpio]                559
# [Barbus barbus]                  306
# [Leuciscus idus]                 304
# [Rutilus rutilus]                288
# [Tinca tinca]                    286
# [Scardinius erythrophthalmus]    281
# [Esox lucius]                    281
# [Sander lucioperca]              272
# [Ctenopharyngodon idella]        263
# [Acipenseridae]                  263
# [Leuciscus cephalus]             252
# [Silurus glanis]                 242
# [Abramis brama]                  241
# [Salmo trutta subsp. fario]      240
# [Anguilla anguilla]              236
# [Perca fluviatilis]              218
# [Blicca bjoerkna]                214
# [Carassius carassius]            212
# [Gymnocephalus cernuus]          206
# [Gobio gobio]                    198
# Name: Class Name, dtype: int64

# %%
# Useful information on Kaggle:
# https://www.kaggle.com/code/reighns/augmentations-data-cleaning-and-bounding-boxes (3 May 23)
# Hiding id behing jpg
#dataframe1["Filepath"] = dataframe1["Filepath"].apply(lambda x: str(x) + ".jpg")
#dataframe1

# %%
# Number of images in dataset and dataframe1
image_count = len(list(dat_dir.glob('*/*.jpg')))
image_count_df = len(dataframe1)
print(image_count)
print(image_count_df)
# Out:
# 5362
# 5362

# %%
# The above count for the dataframe is +1, not sure why

# %% [markdown]
# # Creating the datasets (how to use dataframe1 created above?)

# %% [markdown]
# ### stratified shuffle split
# ### https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedShuffleSplit.html

# %%
X = list(dat_dir.glob(r'**/*.jpg'))
y = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], X))

#sss = StratifiedShuffleSplit(n_splits=5, test_size=0.2, train_size=0.2, random_state=0)
#sss.get_n_splits(X, y)

#print(sss)

#for i, (train_index, test_index) in enumerate(sss.split(X, y)):
#    print(f"Fold {i}:")
#    print(f"  Train: index={train_index}")
#    print(f"  Test:  index={test_index}")

#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, shuffle=True)
#X_train, X_val, y_train, y_val =train_test_split(X_train,y_train,test_size=0.25,random_state=0) # 0.25 x 0.8 0.2"

# %%
#print(X_train)

# %% [markdown]
# # Creating datasets using image dataset from directory

# %% [markdown]
# ### Checking average image size

# %%
#widths = []
#heights = []

#for img_name in os.listdir(dat_dir):
#    if img_name.endswith(".jpg"):
#     img_path = os.path.join(dat_dir, img_name) # Adding img_name to the path
#     im = Image.open(dat_dir)
#     widths.append(im.size[0])
#     heights.append(im.size[1])

#AVG_HEIGHT = round(sum(heights)/len(heights))
#AVG_WIDTH = round(sum(widths)/len(widths))

#print(f"Average Height: {AVG_HEIGHT}")
#print(f"Average Width: {AVG_WIDTH}")

# %%
#img_path

# %%
# Image size
batch_size=32
img_height=180
img_width=180
img_size=(img_height, img_width,3)
num_classes = 20

# %%
img_size
# Out:
# (180, 180, 3)

# %%
# Create the training dataset
train_dataset = tf.keras.utils.image_dataset_from_directory(
  dat_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  shuffle=True,
  image_size=(img_height, img_width),
  color_mode='rgb',
  batch_size=batch_size)
# Out:
# Found 5362 files belonging to 20 classes.
# Using 4290 files for training.

# %%
# Create the validation dataset
val_dataset = tf.keras.utils.image_dataset_from_directory(
  dat_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  shuffle=True,
  image_size=(img_height, img_width),
  color_mode='rgb',
  batch_size=batch_size)
# Out:
# Found 5362 files belonging to 20 classes.
# Using 1072 files for validation.

# %%
# Creating test dataset
test_dataset = tf.keras.utils.image_dataset_from_directory(
  test_dat_dir,
  #validation_split=0.6,
  #subset="validation",
  #seed='123',
  shuffle = True,
  image_size=(img_height, img_width),
  color_mode='rgb',
  batch_size=batch_size)
# Out:
# Found 600 files belonging to 20 classes.

# %%
# Assign the class names
class_names = test_dataset.class_names#test_dataset
#class_names=list1
print(class_names)
# Out:
# ['Abramis brama', 'Acipenseridae', 'Anguilla anguilla', 'Barbus barbus', 'Blicca bjoerkna', 'Carassius carassius', 'Ctenopharyngodon idella', 'Cyprinus carpio', 'Esox lucius', 'Gobio gobio', 'Gymnocephalus cernuus', 'Leuciscus cephalus', 'Leuciscus idus', 'Perca fluviatilis', 'Rutilus rutilus', 'Salmo trutta subsp. fario', 'Sander lucioperca', 'Scardinius erythrophthalmus', 'Silurus glanis', 'Tinca tinca']

# %%
# Next two cells for testing
sample_imgs, sample_labels = test_dataset.as_numpy_iterator().next()
sample_imgs.shape, sample_labels.shape
# Out:
# ((32, 180, 180, 3), (32,))

# %%
#sample_image_boxed = sample_imgs.copy()
#img_bbox = ImageDraw.Draw(sample_image_boxed)
#for i in range(5):
#print(boundBoxList[0])
#img_bbox.rectangle(boundBoxList[0], outline="green")
#sample_image_boxed

# %%
# testing using sample label - to try debug final evaluation
plt.figure(figsize=(10,10))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(sample_imgs[i].astype("uint8")) #images[i].numpy().astype("uint8"))
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title(class_names[sample_labels[i]])
plt.show()

# %% [markdown]
# ### Checking noise in data

# %%
#plt.plot(X.values, list1, linewidth=2, linestyle="-", c="b")#plt.plot(X, y, linewidth=2, linestyle="-", c="b")
#plt.show()
#plt.close()

# %% [markdown]
# ## My model (based on TM358 EMA model)

# %% [markdown]
# ### Data augmentation

# %%
# Creating the normalisation layer
norm_layer = layers.Normalization(input_shape=(img_size))
norm_layer.adapt(train_dataset.map(lambda x, y: x))

# %%
# Creating an augmented subset
data_augmentation = tf.keras.Sequential([
#layers.RandomRotation(0.25),#- worse accuracy (but what about overfitting?) causes freezing at 0.1+
#layers.RandomZoom(height_factor=0.2), # testing cause of model fit freeze
layers.RandomFlip(mode='horizontal'),
layers.RandomFlip(mode='vertical'),# worse but not having it results in overfitting
])

aug_train_dataset = train_dataset.map(lambda x, y: (data_augmentation(x, training=True), y),
num_parallel_calls=tf.data.AUTOTUNE)
aug_train_dataset = aug_train_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ### Model creation

# %% [markdown]
# ### Train the model

# %% [markdown]
# ### Evaluating the model (based on code from TM358)

# %% [markdown]
# # Testing another model (Based on VGG-16)

# %%
ada = tf.keras.optimizers.Adam(learning_rate=0.0001)#learning_rate=0.0001,or 3e-4
def build_model():
      model = Sequential([
          #norm_layer, 
          #Rescaling(1/255),
          Conv2D(filters=64, kernel_size=(3,3), padding="same", input_shape=(img_size), activation= "relu"), 
          Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"),
          MaxPooling2D(pool_size=(2,2)),
          Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"),
          Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"),
          MaxPooling2D(pool_size=(2,2)),
          Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"),
          Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"),
          #Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"),
          MaxPooling2D(pool_size=(2,2)),
          Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
          Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
          #Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
          MaxPooling2D(pool_size=(2,2)),
          Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
          Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
          #Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
          MaxPooling2D(pool_size=(2,2)),
          Dropout(0.5),
          Flatten(),
          #Dense(512, activation='relu'),#
          Dense(512, activation='relu'),# num_classes*25 = 500
          Dropout(0.5),
          Dense(num_classes, activation='softmax')#num_classes * 1.5 or 20 * 1. 
      ])
      model.compile(
          optimizer=ada,#'adam',#learning_rate=0.0001,or 3e-4
          loss='sparse_categorical_crossentropy',#sparse_categorical_crossentropy
          metrics=['accuracy']
          )
      return model

# %%
# Build the model using the build_model function
model=build_model()

# %%
# Show a summary of the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 180, 180, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 180, 180, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 90, 90, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 90, 90, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 45, 45, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 45, 45, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 22, 22, 512)       1180160
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 22, 22, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 11, 11, 512)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 11, 11, 512)       2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 11, 11, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 512)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 5, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               6554112
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                10260
# =================================================================
# Total params: 15,969,364
# Trainable params: 15,969,364
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
#with tf.device("/cpu:0"):
#with tf.device("/device:GPU:0"):
hist=model.fit(
aug_train_dataset,# aug_train_dataset
validation_data=val_dataset, 
verbose=1,
#shuffle=True,
epochs=50)
# Out:
# Epoch 1/50
# 135/135 [==============================] - 45s 245ms/step - loss: 3.0103 - accuracy: 0.0888 - val_loss: 2.9409 - val_accuracy: 0.1185
# Epoch 2/50
# 135/135 [==============================] - 31s 226ms/step - loss: 2.9025 - accuracy: 0.1072 - val_loss: 2.8067 - val_accuracy: 0.1409
# Epoch 3/50
# 135/135 [==============================] - 31s 226ms/step - loss: 2.7724 - accuracy: 0.1434 - val_loss: 2.6589 - val_accuracy: 0.1670
# Epoch 4/50
# 135/135 [==============================] - 31s 226ms/step - loss: 2.6377 - accuracy: 0.1872 - val_loss: 2.5191 - val_accuracy: 0.2015
# Epoch 5/50
# 135/135 [==============================] - 31s 227ms/step - loss: 2.4911 - accuracy: 0.2096 - val_loss: 2.3706 - val_accuracy: 0.2472
# Epoch 6/50
# 135/135 [==============================] - 31s 227ms/step - loss: 2.3303 - accuracy: 0.2741 - val_loss: 2.2124 - val_accuracy: 0.2780
# Epoch 7/50
# 135/135 [==============================] - 31s 228ms/step - loss: 2.1756 - accuracy: 0.3009 - val_loss: 2.2415 - val_accuracy: 0.3032
# Epoch 8/50
# 135/135 [==============================] - 31s 228ms/step - loss: 2.0702 - accuracy: 0.3305 - val_loss: 1.9032 - val_accuracy: 0.4142
# Epoch 9/50
# 135/135 [==============================] - 31s 228ms/step - loss: 1.9603 - accuracy: 0.3797 - val_loss: 1.8278 - val_accuracy: 0.4132
# Epoch 10/50
# 135/135 [==============================] - 31s 228ms/step - loss: 1.8182 - accuracy: 0.4238 - val_loss: 1.8139 - val_accuracy: 0.4328
# Epoch 11/50
# 135/135 [==============================] - 31s 227ms/step - loss: 1.7336 - accuracy: 0.4527 - val_loss: 1.6085 - val_accuracy: 0.4813
# Epoch 12/50
# 135/135 [==============================] - 31s 228ms/step - loss: 1.6147 - accuracy: 0.4862 - val_loss: 1.7634 - val_accuracy: 0.4422
# Epoch 13/50
# 135/135 [==============================] - 31s 228ms/step - loss: 1.5210 - accuracy: 0.5207 - val_loss: 1.6962 - val_accuracy: 0.4636
# Epoch 14/50
# 135/135 [==============================] - 31s 229ms/step - loss: 1.4310 - accuracy: 0.5487 - val_loss: 1.4216 - val_accuracy: 0.5625
# Epoch 15/50
# 135/135 [==============================] - 31s 228ms/step - loss: 1.2914 - accuracy: 0.5939 - val_loss: 1.3416 - val_accuracy: 0.5896
# Epoch 16/50
# 135/135 [==============================] - 31s 228ms/step - loss: 1.2341 - accuracy: 0.6100 - val_loss: 1.5123 - val_accuracy: 0.5429
# Epoch 17/50
# 135/135 [==============================] - 31s 231ms/step - loss: 1.2078 - accuracy: 0.6117 - val_loss: 1.2625 - val_accuracy: 0.6045
# Epoch 18/50
# 135/135 [==============================] - 32s 235ms/step - loss: 1.1255 - accuracy: 0.6371 - val_loss: 1.3005 - val_accuracy: 0.6035
# Epoch 19/50
# 135/135 [==============================] - 32s 234ms/step - loss: 1.1079 - accuracy: 0.6501 - val_loss: 1.3211 - val_accuracy: 0.6138
# Epoch 20/50
# 135/135 [==============================] - 32s 239ms/step - loss: 0.9938 - accuracy: 0.6848 - val_loss: 1.1043 - val_accuracy: 0.6623
# Epoch 21/50
# 135/135 [==============================] - 32s 233ms/step - loss: 0.9518 - accuracy: 0.7000 - val_loss: 1.1468 - val_accuracy: 0.6651
# Epoch 22/50
# 135/135 [==============================] - 32s 238ms/step - loss: 0.8949 - accuracy: 0.7145 - val_loss: 1.1349 - val_accuracy: 0.6576
# Epoch 23/50
# 135/135 [==============================] - 32s 236ms/step - loss: 0.9215 - accuracy: 0.7068 - val_loss: 1.0426 - val_accuracy: 0.7080
# Epoch 24/50
# 135/135 [==============================] - 32s 235ms/step - loss: 0.8239 - accuracy: 0.7352 - val_loss: 1.0238 - val_accuracy: 0.6959
# Epoch 25/50
# 135/135 [==============================] - 31s 232ms/step - loss: 0.7954 - accuracy: 0.7413 - val_loss: 1.0370 - val_accuracy: 0.6950
# Epoch 26/50
# 135/135 [==============================] - 31s 229ms/step - loss: 0.7664 - accuracy: 0.7571 - val_loss: 1.1037 - val_accuracy: 0.6642
# Epoch 27/50
# 135/135 [==============================] - 31s 229ms/step - loss: 0.7327 - accuracy: 0.7660 - val_loss: 0.9879 - val_accuracy: 0.7043
# Epoch 28/50
# 135/135 [==============================] - 32s 233ms/step - loss: 0.6905 - accuracy: 0.7818 - val_loss: 0.9798 - val_accuracy: 0.7071
# Epoch 29/50
# 135/135 [==============================] - 32s 234ms/step - loss: 0.6454 - accuracy: 0.7979 - val_loss: 0.9748 - val_accuracy: 0.7229
# Epoch 30/50
# 135/135 [==============================] - 31s 229ms/step - loss: 0.6031 - accuracy: 0.8107 - val_loss: 1.0145 - val_accuracy: 0.7099
# Epoch 31/50
# 135/135 [==============================] - 31s 228ms/step - loss: 0.6279 - accuracy: 0.7993 - val_loss: 1.0115 - val_accuracy: 0.7276
# Epoch 32/50
# 135/135 [==============================] - 31s 229ms/step - loss: 0.5687 - accuracy: 0.8154 - val_loss: 0.8940 - val_accuracy: 0.7509
# Epoch 33/50
# 135/135 [==============================] - 31s 229ms/step - loss: 0.5227 - accuracy: 0.8322 - val_loss: 0.9125 - val_accuracy: 0.7565
# Epoch 34/50
# 135/135 [==============================] - 31s 228ms/step - loss: 0.5089 - accuracy: 0.8403 - val_loss: 0.9783 - val_accuracy: 0.7369
# Epoch 35/50
# 135/135 [==============================] - 31s 229ms/step - loss: 0.4769 - accuracy: 0.8413 - val_loss: 0.9557 - val_accuracy: 0.7304
# Epoch 36/50
# 135/135 [==============================] - 31s 230ms/step - loss: 0.4828 - accuracy: 0.8473 - val_loss: 1.0443 - val_accuracy: 0.7034
# Epoch 37/50
# 135/135 [==============================] - 31s 228ms/step - loss: 0.4748 - accuracy: 0.8464 - val_loss: 1.0321 - val_accuracy: 0.7304
# Epoch 38/50
# 135/135 [==============================] - 31s 228ms/step - loss: 0.4349 - accuracy: 0.8524 - val_loss: 0.9669 - val_accuracy: 0.7472
# Epoch 39/50
# 135/135 [==============================] - 31s 228ms/step - loss: 0.4502 - accuracy: 0.8524 - val_loss: 0.9390 - val_accuracy: 0.7584
# Epoch 40/50
# 135/135 [==============================] - 31s 229ms/step - loss: 0.4019 - accuracy: 0.8676 - val_loss: 0.9470 - val_accuracy: 0.7612
# Epoch 41/50
# 135/135 [==============================] - 31s 228ms/step - loss: 0.3626 - accuracy: 0.8800 - val_loss: 1.0270 - val_accuracy: 0.7537
# Epoch 42/50
# 135/135 [==============================] - 32s 239ms/step - loss: 0.3598 - accuracy: 0.8821 - val_loss: 0.9472 - val_accuracy: 0.7435
# Epoch 43/50
# 135/135 [==============================] - 32s 236ms/step - loss: 0.3382 - accuracy: 0.8853 - val_loss: 0.9513 - val_accuracy: 0.7491
# Epoch 44/50
# 135/135 [==============================] - 31s 231ms/step - loss: 0.3520 - accuracy: 0.8869 - val_loss: 0.9086 - val_accuracy: 0.7453
# Epoch 45/50
# 135/135 [==============================] - 31s 227ms/step - loss: 0.3055 - accuracy: 0.9016 - val_loss: 1.1092 - val_accuracy: 0.7099
# Epoch 46/50
# 135/135 [==============================] - 31s 227ms/step - loss: 0.3390 - accuracy: 0.8867 - val_loss: 0.9728 - val_accuracy: 0.7537
# Epoch 47/50
# 135/135 [==============================] - 31s 228ms/step - loss: 0.3048 - accuracy: 0.9033 - val_loss: 0.9354 - val_accuracy: 0.7696
# Epoch 48/50
# 135/135 [==============================] - 31s 229ms/step - loss: 0.2544 - accuracy: 0.9152 - val_loss: 1.1843 - val_accuracy: 0.7285
# Epoch 49/50
# 135/135 [==============================] - 31s 229ms/step - loss: 0.2575 - accuracy: 0.9170 - val_loss: 1.1100 - val_accuracy: 0.7323
# Epoch 50/50
# 135/135 [==============================] - 31s 230ms/step - loss: 0.2555 - accuracy: 0.9159 - val_loss: 1.1268 - val_accuracy: 0.7341

# %%
# Plotting training loss and accuracy as well as validation loss and accuracy over the number of epochs
hist_dict = hist.history

# obtain the accuracy and loss of the training set and verification set in the returned
train_acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
train_loss = hist.history['loss']
val_loss = hist.history['val_loss']

epochs = range(1, len(train_acc)+1)
plt.plot(epochs, train_acc, 'bo', label = 'Training acc')
plt.plot(epochs, val_acc, 'r', label = 'Validation acc')
plt.title('Training and validation accuracy')
plt.legend() # show legend 
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
plt.figure()

plt.plot(epochs, train_loss, 'bo', label = 'Training loss')
plt.plot(epochs, val_loss, 'r', label = 'Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
model.evaluate(test_dataset, return_dict=True)
# Out:
# 19/19 [==============================] - 4s 175ms/step - loss: 1.0968 - accuracy: 0.7333
# {'loss': 1.096848487854004, 'accuracy': 0.7333333492279053}

# %%
sample_predictions = model(sample_imgs)
# View the true and predicted labels of sample images
plt.figure(figsize=(15,15))
for i in range(15):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(sample_imgs[i].astype("uint8"))
    #plt.imshow(sample_imgs[i])
    p_class = np.argmax(sample_predictions[i])
    a_class = sample_labels[i]# a_class = np.argmax(sample_labels[i]) ##np.argmax was the problem?!?
    #plt.title(f"P: {class_names[p_class]}\n(A: {class_names[a_class]})",
    plt.title(f"P: {class_names[p_class]}\n(A: {class_names[a_class]})",# class_names[a_class]
    color=("green" if p_class == a_class else "red"))
    plt.axis("off")
plt.show()
